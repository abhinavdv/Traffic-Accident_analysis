# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv("./Accidents Data/Accidents_2010_2013.CSV")
df_2 = pd.read_csv("./Accidents Data/Accidents_2014_2017.CSV")
df_3 = pd.read_csv("./Accidents Data/Accidents_2018_2021.CSV")
# Out:
# C:\Users\mihir\AppData\Local\Temp\ipykernel_1672\1239294947.py:2: DtypeWarning: Columns (28,30,32,40,42,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2 = pd.read_csv("./Accidents Data/Accidents_2014_2017.CSV")
# C:\Users\mihir\AppData\Local\Temp\ipykernel_1672\1239294947.py:3: DtypeWarning: Columns (40,42,64,66,86,88,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_3 = pd.read_csv("./Accidents Data/Accidents_2018_2021.CSV")

# %%
list(df_1)
# Out:
# ['caseyear',
#  'state',
#  'st_case',
#  'statename',
#  've_total',
#  've_forms',
#  'pvh_invl',
#  'peds',
#  'pernotmvit',
#  'permvit',
#  'persons',
#  'county',
#  'countyname',
#  'city',
#  'cityname',
#  'day',
#  'month',
#  'monthname',
#  'year',
#  'day_week',
#  'day_weekname',
#  'hour',
#  'hourname',
#  'minute',
#  'minutename',
#  'nhs',
#  'nhsname',
#  'rur_urb',
#  'rur_urbname',
#  'func_sys',
#  'func_sysname',
#  'rd_owner',
#  'rd_ownername',
#  'route',
#  'routename',
#  'tway_id',
#  'tway_id2',
#  'milept',
#  'mileptname',
#  'latitude',
#  'latitudename',
#  'longitud',
#  'longitudname',
#  'sp_jur',
#  'sp_jurname',
#  'harm_ev',
#  'harm_evname',
#  'man_coll',
#  'man_collname',
#  'reljct1',
#  'reljct1name',
#  'reljct2',
#  'reljct2name',
#  'typ_int',
#  'typ_intname',
#  'wrk_zone',
#  'wrk_zonename',
#  'road_fnc',
#  'road_fncname',
#  'rel_road',
#  'rel_roadname',
#  'lgt_cond',
#  'lgt_condname',
#  'weather1',
#  'weather1name',
#  'weather2',
#  'weather2name',
#  'weather',
#  'weathername',
#  'sch_bus',
#  'sch_busname',
#  'rail',
#  'railname',
#  'not_hour',
#  'not_hourname',
#  'not_min',
#  'not_minname',
#  'arr_hour',
#  'arr_hourname',
#  'arr_min',
#  'arr_minname',
#  'hosp_hr',
#  'hosp_hrname',
#  'hosp_mn',
#  'hosp_mnname',
#  'cf1',
#  'cf1name',
#  'cf2',
#  'cf2name',
#  'cf3',
#  'cf3name',
#  'fatals',
#  'drunk_dr']

# %%
# List of columns you want to select
columns_to_select = [
    "statename",
    "st_case",
    "caseyear",
    "pernotmvit",
    "ve_total",
    "county",
    "permvit",
    "countyname",
    "city",
    "cityname",
    "month",
    "monthname",
    "day",
    "day_week",
    "day_weekname",
    "year",
    "hour",
    "hourname",
    "minute",
    "minutename",
    "tway_id",
    "routename",
    "func_sysname",
    "latitude",
    "longitud",
    "harm_evname",
    "typ_intname",
    "lgt_cond",
    "lgt_condname",
    "weather",
    "weathername",
    "arr_hour",
    "arr_min",
    "fatals"
]

# Selecting specific columns
selected_columns_df_1 = df_1[columns_to_select]
selected_columns_df_2 = df_2[columns_to_select]
selected_columns_df_3 = df_3[columns_to_select]

# %%
accidents_data_2010_2021 = pd.concat([selected_columns_df_1, selected_columns_df_2, selected_columns_df_3], ignore_index=True)

# %%
accidents_data_2010_2021['st_case_per_year'] = accidents_data_2010_2021['caseyear'].astype(str) + '-' + accidents_data_2010_2021['st_case'].astype(str)

# %%
accidents_data_2010_2021
# Out:
#        statename  st_case  caseyear  pernotmvit  ve_total  county  permvit  \
# 0        Alabama    10001      2010         NaN         1      81      NaN
# 1        Alabama    10002      2010         NaN         1      35      NaN
# 2        Alabama    10003      2010         NaN         3      97      NaN
# 3        Alabama    10004      2010         NaN         2     115      NaN
# 4        Alabama    10005      2010         NaN         2     117      NaN
# ...          ...      ...       ...         ...       ...     ...      ...
# 399719   Wyoming   560100      2021         0.0         1      19      2.0
# 399720   Wyoming   560101      2021         0.0         2       3      2.0
# 399721   Wyoming   560102      2021         0.0         1      37      1.0
# 399722   Wyoming   560103      2021         1.0         1      21      1.0
# 399723   Wyoming   560104      2021         0.0         2      23      2.0
#
#              countyname  city        cityname  ...  \
# 0              LEE (81)  2340         OPELIKA  ...
# 1          CONECUH (35)  1080       EVERGREEN  ...
# 2           MOBILE (97)  2100          MOBILE  ...
# 3       ST. CLAIR (115)   160        ASHVILLE  ...
# 4          SHELBY (117)     0  NOT APPLICABLE  ...
# ...                 ...   ...             ...  ...
# 399719     JOHNSON (19)     0  NOT APPLICABLE  ...
# 399720     BIG HORN (3)     0  NOT APPLICABLE  ...
# 399721  SWEETWATER (37)     0  NOT APPLICABLE  ...
# 399722     LARAMIE (21)   100        CHEYENNE  ...
# 399723     LINCOLN (23)     0  NOT APPLICABLE  ...
#
#                         harm_evname          typ_intname  lgt_cond  \
# 0              Tree (Standing Only)  Not an Intersection         3
# 1        Utility Pole/Light Support  Not an Intersection         3
# 2       Motor Vehicle In-Transport        T-Intersection         1
# 3       Motor Vehicle In-Transport   Not an Intersection         3
# 4       Motor Vehicle In-Transport   Not an Intersection         4
# ...                             ...                  ...       ...
# 399719            Rollover/Overturn  Not an Intersection         1
# 399720   Motor Vehicle In-Transport  Not an Intersection         2
# 399721            Rollover/Overturn  Not an Intersection         1
# 399722                   Pedestrian  Not an Intersection         2
# 399723   Motor Vehicle In-Transport  Not an Intersection         2
#
#               lgt_condname weather  weathername  arr_hour arr_min  fatals  \
# 0           Dark - Lighted       1        Clear         4      20       1
# 1           Dark - Lighted       1        Clear         6       9       1
# 2                 Daylight       1        Clear        15      16       1
# 3           Dark - Lighted       2         Rain         1      16       1
# 4                     Dawn       1        Clear         6      49       1
# ...                    ...     ...          ...       ...     ...     ...
# 399719            Daylight       1        Clear         9      16       1
# 399720  Dark - Not Lighted       1        Clear        19       3       1
# 399721            Daylight       1        Clear        99      99       1
# 399722  Dark - Not Lighted       1        Clear        17      17       1
# 399723  Dark - Not Lighted       1        Clear        99      99       1
#
#        st_case_per_year
# 0            2010-10001
# 1            2010-10002
# 2            2010-10003
# 3            2010-10004
# 4            2010-10005
# ...                 ...
# 399719      2021-560100
# 399720      2021-560101
# 399721      2021-560102
# 399722      2021-560103
# 399723      2021-560104
#
# [399724 rows x 35 columns]

# %%
accidents_data_2010_2021.to_csv("AccidentsData_2010-2021.csv")

# %%
df_A = pd.read_csv("./Vehicles Data/Vehicles_2010_2011.CSV")
df_B = pd.read_csv("./Vehicles Data/Vehicles_2012_2014.CSV")
df_C = pd.read_csv("./Vehicles Data/Vehicles_2015_2018.CSV")
df_D = pd.read_csv("./Vehicles Data/Vehicles_2019_2021.CSV")
# Out:
# C:\Users\mihir\AppData\Local\Temp\ipykernel_1672\2757730022.py:1: DtypeWarning: Columns (7,14,44,69,71,114,214) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_A = pd.read_csv("./Vehicles Data/Vehicles_2010_2011.CSV")
# C:\Users\mihir\AppData\Local\Temp\ipykernel_1672\2757730022.py:2: DtypeWarning: Columns (7,69,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_B = pd.read_csv("./Vehicles Data/Vehicles_2012_2014.CSV")
# C:\Users\mihir\AppData\Local\Temp\ipykernel_1672\2757730022.py:3: DtypeWarning: Columns (7,14,57,58,59,60,61,62,69,71,114,141,202,204,206) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_C = pd.read_csv("./Vehicles Data/Vehicles_2015_2018.CSV")
# C:\Users\mihir\AppData\Local\Temp\ipykernel_1672\2757730022.py:4: DtypeWarning: Columns (14,45,47,50,51,53,56,59,61,69,71,74,98,112,114,159,161,163,165,200,216,218,220,222,224,226,228,230,232) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_D = pd.read_csv("./Vehicles Data/Vehicles_2019_2021.CSV")

# %%
import pandas as pd

# Assuming you already have a DataFrame named df

# List of columns you want to extract
columns_to_extract = [
    "ST_CASE",
    "CASEYEAR",
    "VEH_NO",
    "NUMOCCS",
    "BODY_TYP",
    "BODY_TYPNAME",
    "TRAV_SPNAME",
    "DEFORMED",
    "DEFORMEDNAME",
    "VPICMAKE",
    "VPICMAKENAME"
]

# Convert column names to lowercase
columns_to_extract_lower = [col.lower() for col in columns_to_extract]

# Creating a new DataFrame with only the specified columns
vehicle_df_1 = df_A[columns_to_extract_lower]
vehicle_df_2 = df_B[columns_to_extract_lower]
vehicle_df_3 = df_C[columns_to_extract_lower]
vehicle_df_4 = df_D[columns_to_extract_lower]

# %%
vehicles_data_2010_2021 = pd.concat([vehicle_df_1, vehicle_df_2, vehicle_df_3, vehicle_df_4], ignore_index=True)

# %%
vehicles_data_2010_2021['st_case_per_year'] = vehicles_data_2010_2021['caseyear'].astype(str) + '-' + vehicles_data_2010_2021['st_case'].astype(str)

# %%
vehicles_data_2010_2021
# Out:
#         st_case  caseyear  veh_no  numoccs  body_typ  \
# 0         10001      2010       1        2        15
# 1         10002      2010       1        1         4
# 2         10003      2010       1        1        80
# 3         10003      2010       2        1         4
# 4         10003      2010       3        1         4
# ...         ...       ...     ...      ...       ...
# 605019   560101      2021       2        1        93
# 605020   560102      2021       1        1        66
# 605021   560103      2021       1        1        14
# 605022   560104      2021       1        1         4
# 605023   560104      2021       2        1        20
#
#                                              body_typname  \
# 0       Large utility (includes Jeep Cherokee [83 and ...
# 1                                   4-door sedan, hardtop
# 2                                              Motorcycle
# 3                                   4-door sedan, hardtop
# 4                                   4-door sedan, hardtop
# ...                                                   ...
# 605019  Construction equipment other than trucks (incl...
# 605020  Truck-tractor (Cab only, or with any number of...
# 605021  Compact Utility (Utility Vehicle Categories "S...
# 605022                              4-door sedan, hardtop
# 605023  Minivan (Chrysler Town and Country, Caravan, G...
#
#                                 trav_spname  deformed       deformedname  \
# 0                                   Unknown         6   Disabling Damage
# 1                                   Unknown         6   Disabling Damage
# 2                                   Unknown         6   Disabling Damage
# 3                                   010 MPH         4  Functional Damage
# 4       Stopped Motor Vehicle In- Transport         2       Minor Damage
# ...                                     ...       ...                ...
# 605019                              025 MPH         4  Functional Damage
# 605020                              035 MPH         6   Disabling Damage
# 605021                              040 MPH         4  Functional Damage
# 605022                              065 MPH         6   Disabling Damage
# 605023                              060 MPH         6   Disabling Damage
#
#         vpicmake  vpicmakename st_case_per_year
# 0            NaN           NaN       2010-10001
# 1            NaN           NaN       2010-10002
# 2            NaN           NaN       2010-10003
# 3            NaN           NaN       2010-10003
# 4            NaN           NaN       2010-10003
# ...          ...           ...              ...
# 605019    5431.0    John Deere      2021-560101
# 605020     450.0  Freightliner      2021-560102
# 605021     452.0           BMW      2021-560103
# 605022     523.0        Subaru      2021-560104
# 605023     448.0        Toyota      2021-560104
#
# [605024 rows x 12 columns]

# %%
vehicles_data_2010_2021.to_csv("VehiclesData_2010-2021.csv")

# %%
df_PerA = pd.read_csv("./Persons Data/Persons_2010_2013.CSV")
df_PerB = pd.read_csv("./Persons Data/Persons_2014_2017.CSV")
df_PerC = pd.read_csv("./Persons Data/Persons_2018_2021.CSV")
# Out:
# C:\Users\mihir\AppData\Local\Temp\ipykernel_19320\1255216158.py:1: DtypeWarning: Columns (8,17,115,117) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_PerA = pd.read_csv("./Persons Data/Persons_2010_2013.CSV")
# C:\Users\mihir\AppData\Local\Temp\ipykernel_19320\1255216158.py:2: DtypeWarning: Columns (8,17,19,113,115,117,118,128,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_PerB = pd.read_csv("./Persons Data/Persons_2014_2017.CSV")
# C:\Users\mihir\AppData\Local\Temp\ipykernel_19320\1255216158.py:3: DtypeWarning: Columns (8,17,113,115,117,124) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_PerC = pd.read_csv("./Persons Data/Persons_2018_2021.CSV")

# %%
# List of specific columns you want to extract
columns_to_extract = ["st_case", "caseyear", "veh_no", "per_no", "age", "sex", "per_typ", "per_typname", 
                      "inj_sev", "inj_sevname", "rest_use", "rest_usename", "drinking", 
                      "drinkingname", "drugs", "drugsname", "doa", "doaname"]

# Creating a new DataFrame with only the specified columns
person_df_1 = df_PerA[columns_to_extract]
person_df_2 = df_PerB[columns_to_extract]
person_df_3 = df_PerC[columns_to_extract]

# %%
person_data_2010_2021 = pd.concat([person_df_1, person_df_2, person_df_3], ignore_index=True)

# %%
person_data_2010_2021['st_case_per_year'] = person_data_2010_2021['caseyear'].astype(str) + '-' + person_data_2010_2021['st_case'].astype(str)

# %%
person_data_2010_2021
# Out:
#         st_case  caseyear  veh_no  per_no  age  sex  per_typ  \
# 0         10001      2010       1       1   51    2        1
# 1         10001      2010       1       2  999    1        2
# 2         10002      2010       1       1   44    2        1
# 3         10003      2010       1       1   27    1        1
# 4         10003      2010       2       1   45    2        1
# ...         ...       ...     ...     ...  ...  ...      ...
# 984980   560102      2021       1       1   61    1        1
# 984981   560103      2021       0       1   62    1        5
# 984982   560103      2021       1       1   32    1        1
# 984983   560104      2021       1       1   58    1        1
# 984984   560104      2021       2       1   49    2        1
#
#                                       per_typname  inj_sev  \
# 0          Driver of a Motor Vehicle In-Transport        4
# 1       Passenger of a Motor Vehicle In-Transport        3
# 2          Driver of a Motor Vehicle In-Transport        4
# 3          Driver of a Motor Vehicle In-Transport        4
# 4          Driver of a Motor Vehicle In-Transport        0
# ...                                           ...      ...
# 984980     Driver of a Motor Vehicle In-Transport        4
# 984981                                 Pedestrian        4
# 984982     Driver of a Motor Vehicle In-Transport        0
# 984983     Driver of a Motor Vehicle In-Transport        4
# 984984     Driver of a Motor Vehicle In-Transport        2
#
#                        inj_sevname  rest_use  \
# 0                 Fatal Injury (K)         7
# 1        Incapacitating Injury (A)         7
# 2                 Fatal Injury (K)         7
# 3                 Fatal Injury (K)         5
# 4                    No Injury (O)         3
# ...                            ...       ...
# 984980            Fatal Injury (K)        20
# 984981            Fatal Injury (K)        96
# 984982      No Apparent Injury (O)         3
# 984983            Fatal Injury (K)        20
# 984984  Suspected Minor Injury (B)         3
#
#                             rest_usename  drinking               drinkingname  \
# 0       None Used-Motor Vehicle Occupant         9  Unknown (Police Reported)
# 1       None Used-Motor Vehicle Occupant         8               Not Reported
# 2       None Used-Motor Vehicle Occupant         0  No (Alcohol Not Involved)
# 3        DOT-Compliant Motorcycle Helmet         9  Unknown (Police Reported)
# 4             Shoulder and Lap Belt Used         0  No (Alcohol Not Involved)
# ...                                  ...       ...                        ...
# 984980          None Used/Not Applicable         0  No (Alcohol Not Involved)
# 984981      Not a Motor Vehicle Occupant         1     Yes (Alcohol Involved)
# 984982        Shoulder and Lap Belt Used         0  No (Alcohol Not Involved)
# 984983          None Used/Not Applicable         0  No (Alcohol Not Involved)
# 984984        Shoulder and Lap Belt Used         0  No (Alcohol Not Involved)
#
#         drugs                drugsname  doa         doaname st_case_per_year
# 0           9                  Unknown    7   Died at Scene       2010-10001
# 1           8             Not Reported    0  Not Applicable       2010-10001
# 2           0  No (drugs not involved)    0  Not Applicable       2010-10002
# 3           9                  Unknown    0  Not Applicable       2010-10003
# 4           0  No (drugs not involved)    0  Not Applicable       2010-10003
# ...       ...                      ...  ...             ...              ...
# 984980      0  No (drugs not involved)    7   Died at Scene      2021-560102
# 984981      9      Reported as Unknown    7   Died at Scene      2021-560103
# 984982      0  No (drugs not involved)    0  Not Applicable      2021-560103
# 984983      1     Yes (drugs involved)    7   Died at Scene      2021-560104
# 984984      0  No (drugs not involved)    0  Not Applicable      2021-560104
#
# [984985 rows x 19 columns]

# %%
person_data_2010_2021.to_csv("CombinedPersonData_2010-2021.csv")

# %%
df = pd.read_csv("MergedData.csv")
df
# Out:
# C:\Users\mihir\AppData\Local\Temp\ipykernel_1672\1678598123.py:1: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("MergedData.csv")
#              statename  st_case  pernotmvit  ve_total  county  permvit  \
# 0             Colorado    80082           0         3      69        5
# 1              Florida   120857           0         2      81        2
# 2       North Carolina   370598           0         2      51        2
# 3                 Utah   490100           0         2      49        2
# 4       North Carolina   370723           0         2      65        2
# ...                ...      ...         ...       ...     ...      ...
# 559709         Florida   121293           0         2      19        3
# 559710         Florida   121344           0         2      57        3
# 559711         Florida   121430           0         2      71        2
# 559712         Florida   121505           0         2      91        2
# 559713         Florida   121507           0         2      57        2
#
#        countyname - Split 1        cityname  month monthname  ...  numoccs  \
# 0                   LARIMER        LOVELAND      3     March  ...        1
# 1                   MANATEE       BRADENTON      3     March  ...        1
# 2                CUMBERLAND    FAYETTEVILLE      6      June  ...        1
# 3                      UTAH            OREM      7      July  ...        1
# 4                 EDGECOMBE     Rocky Mound      8    August  ...        1
# ...                     ...             ...    ...       ...  ...      ...
# 559709                 CLAY  NOT APPLICABLE      5       May  ...        1
# 559710         HILLSBOROUGH  NOT APPLICABLE      6      June  ...        1
# 559711                  LEE  NOT APPLICABLE      7      July  ...        1
# 559712             OKALOOSA  NOT APPLICABLE      6      June  ...        1
# 559713         HILLSBOROUGH           TAMPA      6      June  ...        1
#
#        body_typ                                     body_typname trav_spname  \
# 0            80  Two Wheel Motorcycle (excluding motor scooters)     065 MPH
# 1            80  Two Wheel Motorcycle (excluding motor scooters)     065 MPH
# 2            80  Two Wheel Motorcycle (excluding motor scooters)     065 MPH
# 3            80  Two Wheel Motorcycle (excluding motor scooters)     065 MPH
# 4            80  Two Wheel Motorcycle (excluding motor scooters)     066 MPH
# ...         ...                                              ...         ...
# 559709       80  Two Wheel Motorcycle (excluding motor scooters)     045 MPH
# 559710       80  Two Wheel Motorcycle (excluding motor scooters)     045 MPH
# 559711       80  Two Wheel Motorcycle (excluding motor scooters)     045 MPH
# 559712       80  Two Wheel Motorcycle (excluding motor scooters)     045 MPH
# 559713       80  Two Wheel Motorcycle (excluding motor scooters)     045 MPH
#
#         deformed      deformedname vpicmake vpicmakename  caseyear  \
# 0              6  Disabling Damage    564.0       Yamaha      2020
# 1              6  Disabling Damage    564.0       Yamaha      2020
# 2              6  Disabling Damage    564.0       Yamaha      2020
# 3              6  Disabling Damage    564.0       Yamaha      2020
# 4              6  Disabling Damage    509.0       Suzuki      2020
# ...          ...               ...      ...          ...       ...
# 559709         6  Disabling Damage      NaN          NaN      2019
# 559710         6  Disabling Damage      NaN          NaN      2019
# 559711         6  Disabling Damage      NaN          NaN      2019
# 559712         6  Disabling Damage      NaN          NaN      2019
# 559713         6  Disabling Damage      NaN          NaN      2019
#
#         st_case_per_year
# 0             2020-80082
# 1            2020-120857
# 2            2020-370598
# 3            2020-490100
# 4            2020-370723
# ...                  ...
# 559709       2019-121293
# 559710       2019-121344
# 559711       2019-121430
# 559712       2019-121505
# 559713       2019-121507
#
# [559714 rows x 41 columns]
